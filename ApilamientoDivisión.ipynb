# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Slicing dimensions

# %%
rgb = np.array([[[255, 0, 0], [255, 255, 0], [255, 255, 255]], 
[[255, 0, 255], [0, 255, 0], [0, 255, 255]], 
[[0, 0, 0], [0, 255, 255], [0, 0, 255]]]) 
red_array = rgb[:, :, 0] 
green_array = rgb[:, :, 1] 
blue_array = rgb[:, :, 2] 
red_array
# Out:
# array([[255, 255, 255],
#        [255,   0,   0],
#        [  0,   0,   0]])

# %% [markdown]
# División de matrices

# %%
red_array, green_array, blue_array = np.split(rgb, 3, axis=2) 
red_array
# Out:
# array([[[255],
#         [255],
#         [255]],
#
#        [[255],
#         [  0],
#         [  0]],
#
#        [[  0],
#         [  0],
#         [  0]]])

# %%
red_array.shape
# Out:
# (3, 3, 1)

# %% [markdown]
# Trailing dimensions

# %%
red_array_2D = red_array.reshape((3, 3)) 
red_array_2D
# Out:
# array([[255, 255, 255],
#        [255,   0,   0],
#        [  0,   0,   0]])

# %%
red_array_2D.shape
# Out:
# (3, 3)

# %%
with open("logo.npy", "rb") as f:
    logo_rgb_array = np.load(f) 
plt.imshow(logo_rgb_array) 
plt.show()

# %%
red_array = logo_rgb_array[:, :, 0] 
blue_array = logo_rgb_array[:, :, 1] 
green_array = logo_rgb_array[:, :, 2]

# %%
red_array[1], green_array[1], blue_array[1]
# Out:
# (array([253, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 254, 254,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255,
#         255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255,
#         255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255,
#         255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         254, 254, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 254, 254,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255,
#         255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255,
#         255, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255,
#         255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         254, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255], dtype=uint8),
#  array([252, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255,
#         255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 254, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255,
#         254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         254, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 254, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 254, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255,
#         255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255,
#         255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255,
#         255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254,
#         254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 254,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         254, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 254, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 254, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 254, 255, 255,
#         255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 254, 255, 255, 255, 254, 254, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 255, 255,
#         254, 255, 255, 255, 255, 255, 255], dtype=uint8),
#  array([253, 255, 255, 254, 255, 255, 255, 255, 255, 255, 254, 254, 255,
#         255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255,
#         254, 254, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 255,
#         255, 255, 255, 254, 255, 255, 255, 254, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255,
#         255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 254, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         254, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254,
#         254, 255, 255, 255, 255, 255, 255, 255, 254, 255, 255, 255, 254,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255,
#         255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255, 255,
#         254, 255, 255, 255, 254, 254, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 255,
#         255, 255, 254, 254, 255, 255, 255, 254, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255,
#         255, 255, 255, 255, 255, 254, 255, 255, 255, 254, 254, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         254, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254,
#         254, 255, 255, 255, 255, 255, 255, 254, 254, 255, 255, 255, 254,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 254, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 254, 255, 255, 255, 255], dtype=uint8))

# %% [markdown]
# Reglas de división de matrices

# %%
red_array, green_array, blue_array = np.split(rgb, 5, axis=2) 
# La división de matrices no da como resultado una división igual
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 red_array, green_array, blue_array = np.split(rgb, 5, axis=2)
#       2 # La división de matrices no da como resultado una división igual
#
# File c:\Users\valer\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_shape_base_impl.py:889, in split(ary, indices_or_sections, axis)
#     887     N = ary.shape[axis]
#     888     if N % sections:
# --> 889         raise ValueError(
#     890             'array split does not result in an equal division') from None
#     891 return array_split(ary, indices_or_sections, axis)
#
# ValueError: array split does not result in an equal division

# %% [markdown]
# Trazado de datos de imágenes 2D

# %%
red_array, green_array, blue_array = np.split(logo_rgb_array, 3, axis=2) 
plt.imshow(red_array) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 red_array, green_array, blue_array = np.split(logo_rgb_array, 3, axis=2)
#       2 plt.imshow(red_array)
#       3 plt.show()
#
# File c:\Users\valer\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_shape_base_impl.py:889, in split(ary, indices_or_sections, axis)
#     887     N = ary.shape[axis]
#     888     if N % sections:
# --> 889         raise ValueError(
#     890             'array split does not result in an equal division') from None
#     891 return array_split(ary, indices_or_sections, axis)
#
# ValueError: array split does not result in an equal division

# %% [markdown]
# Stacking 2D arrays

# %%
red_array = np.zeros((1001, 1001)).astype(np.int32) 
green_array = green_array.reshape((1001, 1001)) 
blue_array = blue_array.reshape((1001, 1001))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 2
#       1 red_array = np.zeros((1001, 1001)).astype(np.int32)
# ----> 2 green_array = green_array.reshape((1001, 1001))
#       3 blue_array = blue_array.reshape((1001, 1001))
#
# ValueError: cannot reshape array of size 467855 into shape (1001,1001)

# %%
stacked_rgb = np.stack([red_array, green_array, blue_array], axis=2) 
plt.imshow(stacked_rgb) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 stacked_rgb = np.stack([red_array, green_array, blue_array], axis=2)
#       2 plt.imshow(stacked_rgb)
#       3 plt.show()
#
# File c:\Users\valer\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\shape_base.py:457, in stack(arrays, axis, out, dtype, casting)
#     455 shapes = {arr.shape for arr in arrays}
#     456 if len(shapes) != 1:
# --> 457     raise ValueError('all input arrays must have the same shape')
#     459 result_ndim = arrays[0].ndim + 1
#     460 axis = normalize_axis_index(axis, result_ndim)
#
# ValueError: all input arrays must have the same shape
